# %%
from __future__ import print_function

import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn import tree

from matplotlib import pyplot
import numpy as np
import random
# %matplotlib inline
pd.options.mode.chained_assignment = None
bank = pd.read_csv('bank-full.csv',sep=";")

# %%
m = bank.shape[1]
X = bank.iloc[:,0:(m-1)]
y = bank.iloc[:,(m-1):]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=33)

# %%
X_train.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# dtype: object

# %%
X_train_onehot = pd.get_dummies(X_train)
X_test_onehot = pd.get_dummies(X_test)
y_train.loc[:,'y'] = y_train.loc[:,'y'].map({'no':0,'yes':1})
y_test.loc[:,'y'] = y_test.loc[:,'y'].map({'no':0,'yes':1})

# %%
X_train_onehot
# Out:
#        age  balance  day  duration  campaign  pdays  previous  job_admin.  \
# 38015   30      303   14       176         2    365         4           0
# 44341   29        0   29        99         6     -1         0           0
# 24269   49        7   17        50         1     -1         0           0
# 4680    38      273   20       314         2     -1         0           0
# 6450    45     -173   27       315         2     -1         0           1
# 15252   27       24   17       320         2     -1         0           0
# 28981   50     1088    2       749         1     -1         0           0
# 41779   74     1124   13       200         2     -1         0           0
# 11037   39     1551   17       264        16     -1         0           0
# 18916   53        0    4       134         2     -1         0           0
# 32795   52      940   17       317         1     -1         0           0
# 12291   34        1   25        53         1     -1         0           0
# 7898    31      292   30        30        18     -1         0           0
# 5960    32      782   26       116         4     -1         0           0
# 32355   20     1681   16       130         1     -1         0           0
# 32701   60        0   17        68         3    343         1           0
# 37473   41     -664   13       185         4     -1         0           0
# 8941    44        0    4       389         5     -1         0           0
# 39660   29     2305   27        82         2     -1         0           0
# 11302   47      197   18        57         2     -1         0           0
# 13284   36      110    8       291         2     -1         0           0
# 34127   26      507   30       380         1     -1         0           0
# 44176   34     2733   14       604         1     -1         0           0
# 18778   41      188   31        15        25     -1         0           0
# 19485   40     1076    7       326         2     -1         0           0
# 41119   36      953   17        80         1     81         2           1
# 39674   58     -235   27        93         2     -1         0           0
# 38032   31     1750   14        90         3     -1         0           0
# 18996   42     9720    5        81         2     -1         0           0
# 36510   58      502   12       197         2    370         3           0
# ...    ...      ...  ...       ...       ...    ...       ...         ...
# 27203   41      832   21       164         1    176         1           0
# 25226   36      -92   18       196         3     -1         0           0
# 27655   32      665   21        22         5     -1         0           0
# 4195    42      365   19        49         2     -1         0           0
# 17353   59        0   28        97         2     -1         0           0
# 535     45      756    6       179         2     -1         0           0
# 25320   40     5674   18        84         1     -1         0           0
# 45140   63     3904    8       360         1     96         4           0
# 36086   45     1265   11        40         8    299         1           0
# 18282   43      352   31       165         4     -1         0           1
# 30544   43     1022    5       163         3    276         2           1
# 14731   40      884   15       166         4     -1         0           0
# 32487   37      346   17       390         1    316         1           0
# 23724   33       34   28        13        30     -1         0           0
# 2591    37     1330   13        60         1     -1         0           0
# 33613   39     1107   20       407         4     -1         0           0
# 1569    41     -417    8        51         3     -1         0           0
# 26403   32    11512   20       301         1    183         1           0
# 21293   55      987   18        63         4     -1         0           0
# 34812   40      102    6       168         1     -1         0           0
# 34877   29        0    6       315         1    281        15           0
# 16486   60      591   23       248         2     -1         0           0
# 10435   43     5658   12       462         3     -1         0           0
# 57      47      306    5        13         1     -1         0           0
# 27849   26     3244   28       390         1     -1         0           0
# 27282   32     6710   21        48         1     -1         0           0
# 578     53       25    6       266         3     -1         0           0
# 38616   43     -266   15        12         5     -1         0           0
# 2439    45     4646   13       118         1     -1         0           0
# 23572   37     6743   28        13        13     -1         0           0
#
#        job_blue-collar  job_entrepreneur        ...         month_jun  \
# 38015                0                 1        ...                 0
# 44341                0                 0        ...                 0
# 24269                0                 0        ...                 0
# 4680                 0                 0        ...                 0
# 6450                 0                 0        ...                 0
# 15252                0                 0        ...                 0
# 28981                0                 0        ...                 0
# 41779                0                 0        ...                 0
# 11037                1                 0        ...                 1
# 18916                0                 0        ...                 0
# 32795                1                 0        ...                 0
# 12291                0                 0        ...                 1
# 7898                 1                 0        ...                 0
# 5960                 0                 0        ...                 0
# 32355                0                 0        ...                 0
# 32701                0                 0        ...                 0
# 37473                1                 0        ...                 0
# 8941                 0                 0        ...                 1
# 39660                0                 0        ...                 0
# 11302                0                 0        ...                 1
# 13284                1                 0        ...                 0
# 34127                0                 0        ...                 0
# 44176                0                 0        ...                 0
# 18778                0                 0        ...                 0
# 19485                0                 0        ...                 0
# 41119                0                 0        ...                 0
# 39674                0                 0        ...                 0
# 38032                0                 0        ...                 0
# 18996                0                 0        ...                 0
# 36510                0                 0        ...                 0
# ...                ...               ...        ...               ...
# 27203                0                 0        ...                 0
# 25226                0                 0        ...                 0
# 27655                0                 0        ...                 0
# 4195                 0                 0        ...                 0
# 17353                0                 0        ...                 0
# 535                  1                 0        ...                 0
# 25320                0                 0        ...                 0
# 45140                0                 1        ...                 0
# 36086                1                 0        ...                 0
# 18282                0                 0        ...                 0
# 30544                0                 0        ...                 0
# 14731                0                 0        ...                 0
# 32487                1                 0        ...                 0
# 23724                0                 0        ...                 0
# 2591                 0                 0        ...                 0
# 33613                0                 0        ...                 0
# 1569                 0                 0        ...                 0
# 26403                0                 0        ...                 0
# 21293                0                 0        ...                 0
# 34812                0                 0        ...                 0
# 34877                0                 0        ...                 0
# 16486                0                 0        ...                 0
# 10435                0                 0        ...                 1
# 57                   1                 0        ...                 0
# 27849                0                 0        ...                 0
# 27282                0                 0        ...                 0
# 578                  1                 0        ...                 0
# 38616                0                 0        ...                 0
# 2439                 1                 0        ...                 0
# 23572                0                 0        ...                 0
#
#        month_mar  month_may  month_nov  month_oct  month_sep  \
# 38015          0          1          0          0          0
# 44341          0          0          0          0          0
# 24269          0          0          1          0          0
# 4680           0          1          0          0          0
# 6450           0          1          0          0          0
# 15252          0          0          0          0          0
# 28981          0          0          0          0          0
# 41779          0          0          0          1          0
# 11037          0          0          0          0          0
# 18916          0          0          0          0          0
# 32795          0          0          0          0          0
# 12291          0          0          0          0          0
# 7898           0          1          0          0          0
# 5960           0          1          0          0          0
# 32355          0          0          0          0          0
# 32701          0          0          0          0          0
# 37473          0          1          0          0          0
# 8941           0          0          0          0          0
# 39660          0          1          0          0          0
# 11302          0          0          0          0          0
# 13284          0          0          0          0          0
# 34127          0          0          0          0          0
# 44176          0          0          0          0          0
# 18778          0          0          0          0          0
# 19485          0          0          0          0          0
# 41119          0          0          0          0          0
# 39674          0          1          0          0          0
# 38032          0          1          0          0          0
# 18996          0          0          0          0          0
# 36510          0          1          0          0          0
# ...          ...        ...        ...        ...        ...
# 27203          0          0          1          0          0
# 25226          0          0          1          0          0
# 27655          0          0          1          0          0
# 4195           0          1          0          0          0
# 17353          0          0          0          0          0
# 535            0          1          0          0          0
# 25320          0          0          1          0          0
# 45140          0          0          1          0          0
# 36086          0          1          0          0          0
# 18282          0          0          0          0          0
# 30544          0          0          0          0          0
# 14731          0          0          0          0          0
# 32487          0          0          0          0          0
# 23724          0          0          0          0          0
# 2591           0          1          0          0          0
# 33613          0          0          0          0          0
# 1569           0          1          0          0          0
# 26403          0          0          1          0          0
# 21293          0          0          0          0          0
# 34812          0          1          0          0          0
# 34877          0          1          0          0          0
# 16486          0          0          0          0          0
# 10435          0          0          0          0          0
# 57             0          1          0          0          0
# 27849          0          0          0          0          0
# 27282          0          0          1          0          0
# 578            0          1          0          0          0
# 38616          0          1          0          0          0
# 2439           0          1          0          0          0
# 23572          0          0          0          0          0
#
#        poutcome_failure  poutcome_other  poutcome_success  poutcome_unknown
# 38015                 1               0                 0                 0
# 44341                 0               0                 0                 1
# 24269                 0               0                 0                 1
# 4680                  0               0                 0                 1
# 6450                  0               0                 0                 1
# 15252                 0               0                 0                 1
# 28981                 0               0                 0                 1
# 41779                 0               0                 0                 1
# 11037                 0               0                 0                 1
# 18916                 0               0                 0                 1
# 32795                 0               0                 0                 1
# 12291                 0               0                 0                 1
# 7898                  0               0                 0                 1
# 5960                  0               0                 0                 1
# 32355                 0               0                 0                 1
# 32701                 0               1                 0                 0
# 37473                 0               0                 0                 1
# 8941                  0               0                 0                 1
# 39660                 0               0                 0                 1
# 11302                 0               0                 0                 1
# 13284                 0               0                 0                 1
# 34127                 0               0                 0                 1
# 44176                 0               0                 0                 1
# 18778                 0               0                 0                 1
# 19485                 0               0                 0                 1
# 41119                 1               0                 0                 0
# 39674                 0               0                 0                 1
# 38032                 0               0                 0                 1
# 18996                 0               0                 0                 1
# 36510                 1               0                 0                 0
# ...                 ...             ...               ...               ...
# 27203                 1               0                 0                 0
# 25226                 0               0                 0                 1
# 27655                 0               0                 0                 1
# 4195                  0               0                 0                 1
# 17353                 0               0                 0                 1
# 535                   0               0                 0                 1
# 25320                 0               0                 0                 1
# 45140                 0               0                 1                 0
# 36086                 0               0                 1                 0
# 18282                 0               0                 0                 1
# 30544                 1               0                 0                 0
# 14731                 0               0                 0                 1
# 32487                 1               0                 0                 0
# 23724                 0               0                 0                 1
# 2591                  0               0                 0                 1
# 33613                 0               0                 0                 1
# 1569                  0               0                 0                 1
# 26403                 1               0                 0                 0
# 21293                 0               0                 0                 1
# 34812                 0               0                 0                 1
# 34877                 0               1                 0                 0
# 16486                 0               0                 0                 1
# 10435                 0               0                 0                 1
# 57                    0               0                 0                 1
# 27849                 0               0                 0                 1
# 27282                 0               0                 0                 1
# 578                   0               0                 0                 1
# 38616                 0               0                 0                 1
# 2439                  0               0                 0                 1
# 23572                 0               0                 0                 1
#
# [33908 rows x 51 columns]

# %%
T=50 #Max number of trees

m = X_train_onehot.shape[0]
N = X_train_onehot.shape[1]
feature_portion = 0.5
W = [1.0/m for i in range(0,m,1)]
W = pd.DataFrame({'Weight':list(W)},index = X_train_onehot.index)
feature_record = pd.DataFrame()

# List of trees
clfs = []
# List of weights of trees
alphas = []

for i in range(1,T+1):
    # Prepare training sample subset (bagging)
    X_train_onehot_sample, X_test_onehot_sample, y_train_sample, y_test_sample = train_test_split(X_train_onehot, y_train, test_size=0.33, random_state=33)
    selected_features =  [random.randint(0,N-1) for j in range(0,int(round(N*feature_portion)))]
    feature_record=feature_record.append(pd.DataFrame([selected_features]), ignore_index=True)    
    X_train_onehot_sample = X_train_onehot_sample.iloc[:,selected_features]
    X_test_onehot_sample = X_test_onehot_sample.iloc[:,selected_features]
    # Prepare tree classifier
    clf = tree.DecisionTreeClassifier(criterion='entropy',max_depth=None)
    # Weight of current training sample
    w_ = W.loc[X_train_onehot_sample.index,"Weight"].tolist()
    
    # Train decision tree
    clf.fit(X=X_train_onehot_sample, y=y_train_sample,sample_weight=w_)
    # Make prediction
    pred = clf.predict(X_train_onehot.iloc[:,selected_features])
    
    # Calculate weighted error rate of current tree
    print("sum(np.array(W)): {}".format(sum(np.array(W))))
    eps = 1-sum(np.array(W)[(np.array(pred) == np.array(y_train))[0]])/sum(np.array(W))
    print("eps: {}".format(eps))
    # Compute weight of decision tree
    alpha = (1/2)*np.log( (m-1)*(1-eps)/eps )
    alphas.append(alpha)
    
    print( np.array([ int(y==p) for y,p in zip(np.ravel(y_train), pred) ])[np.where(w>0)]         )
    
    # Update weight of training sample
    if alpha > 0 :
        exp_alphas = [ np.exp(-alpha) if y==p else np.exp(alpha) for y,p in zip(np.ravel(y_train), pred) ]
        W = np.multiply(W, exp_alphas) / np.sum(np.multiply(W, exp_alphas))

        
        # Save trained tree to list 
        clfs.append(clf)
    # If alpha < 0, reject the tree
        print('in if then loop')
    else :
        print("Tree {} is rejected.".format(i))


        

    
    #X.iloc[X_train.index,:]
    print('The accuracy of Tree ',str(i), ' is ',round(clf.score(X=X_test_onehot_sample, y=y_test_sample),5),sep='')
# Out:
# sum(np.array(W)): [1.]
# eps: [0.03943022]
# in if then loop
# The accuracy of Tree 1 is 0.88776
# sum(np.array(W)): [1.]
# eps: [0.79909492]
# in if then loop
# The accuracy of Tree 2 is 0.42761
# sum(np.array(W)): [1.]
# eps: [0.25455069]
# in if then loop
# The accuracy of Tree 3 is 0.82046
# sum(np.array(W)): [1.]
# eps: [0.36584524]
# in if then loop
# The accuracy of Tree 4 is 0.8571
# sum(np.array(W)): [1.]
# eps: [0.26416616]
# in if then loop
# The accuracy of Tree 5 is 0.74987
# sum(np.array(W)): [1.]
# eps: [0.32692949]
# in if then loop
# The accuracy of Tree 6 is 0.86309
# sum(np.array(W)): [1.]
# eps: [0.22857472]
# in if then loop
# The accuracy of Tree 7 is 0.85871
# sum(np.array(W)): [1.]
# eps: [0.31167766]
# in if then loop
# The accuracy of Tree 8 is 0.8496
# sum(np.array(W)): [1.]
# eps: [0.22640941]
# in if then loop
# The accuracy of Tree 9 is 0.779
# sum(np.array(W)): [1.]
# eps: [0.19510943]
# in if then loop
# The accuracy of Tree 10 is 0.82046
# sum(np.array(W)): [1.]
# eps: [0.18181649]
# in if then loop
# The accuracy of Tree 11 is 0.76354
# sum(np.array(W)): [1.]
# eps: [0.22221815]
# in if then loop
# The accuracy of Tree 12 is 0.8496
# sum(np.array(W)): [1.]
# eps: [0.33330013]
# in if then loop
# The accuracy of Tree 13 is 0.85085
# sum(np.array(W)): [1.]
# eps: [0.0714717]
# in if then loop
# The accuracy of Tree 14 is 0.80894
# sum(np.array(W)): [1.]
# eps: [0.2307323]
# in if then loop
# The accuracy of Tree 15 is 0.85317
# sum(np.array(W)): [1.]
# eps: [0.39990272]
# in if then loop
# The accuracy of Tree 16 is 0.84155
# sum(np.array(W)): [1.]
# eps: [8.30780655e-05]
# in if then loop
# The accuracy of Tree 17 is 0.80634
# sum(np.array(W)): [1.]
# eps: [0.16662062]
# in if then loop
# The accuracy of Tree 18 is 0.79902
# sum(np.array(W)): [1.]
# eps: [0.20011927]
# in if then loop
# The accuracy of Tree 19 is 0.6387
# sum(np.array(W)): [1.]
# eps: [0.50003624]
# in if then loop
# The accuracy of Tree 20 is 0.56685
# sum(np.array(W)): [1.]
# eps: [3.57360946e-06]
# in if then loop
# The accuracy of Tree 21 is 0.78579
# sum(np.array(W)): [1.]
# eps: [0.49992313]
# in if then loop
# The accuracy of Tree 22 is 0.83861
# sum(np.array(W)): [1.]
# eps: [0.00013199]
# in if then loop
# The accuracy of Tree 23 is 0.74933
# sum(np.array(W)): [1.]
# eps: [2.9496518e-05]
# in if then loop
# The accuracy of Tree 24 is 0.81072
# sum(np.array(W)): [1.]
# eps: [3.60305006e-05]
# in if then loop
# The accuracy of Tree 25 is 0.8277
# sum(np.array(W)): [1.]
# eps: [9.30804767e-10]
# in if then loop
# The accuracy of Tree 26 is 0.74692
# sum(np.array(W)): [1.]
# eps: [4.60405225e-09]
# in if then loop
# The accuracy of Tree 27 is 0.67006
# sum(np.array(W)): [1.]
# eps: [5.31538979e-09]
# in if then loop
# The accuracy of Tree 28 is 0.72654
# sum(np.array(W)): [1.]
# eps: [0.00011728]
# in if then loop
# The accuracy of Tree 29 is 0.77006
# sum(np.array(W)): [1.]
# eps: [2.94928825e-05]
# in if then loop
# The accuracy of Tree 30 is 0.70518
# sum(np.array(W)): [1.]
# eps: [0.00011729]
# in if then loop
# The accuracy of Tree 31 is 0.67256
# sum(np.array(W)): [1.]
# eps: [2.56461519e-14]
# in if then loop
# The accuracy of Tree 32 is 0.75889
# sum(np.array(W)): [1.]
# eps: [4.05786516e-13]
# in if then loop
# The accuracy of Tree 33 is 0.66604
# sum(np.array(W)): [1.]
# eps: [0.]
# in if then loop
# The accuracy of Tree 34 is 0.67828
# sum(np.array(W)): [nan]
# /anaconda3/envs/face/lib/python3.6/site-packages/ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# eps: [nan]
# Tree 35 is rejected.
# The accuracy of Tree 35 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 36 is rejected.
# The accuracy of Tree 36 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 37 is rejected.
# The accuracy of Tree 37 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 38 is rejected.
# The accuracy of Tree 38 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 39 is rejected.
# The accuracy of Tree 39 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 40 is rejected.
# The accuracy of Tree 40 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 41 is rejected.
# The accuracy of Tree 41 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 42 is rejected.
# The accuracy of Tree 42 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 43 is rejected.
# The accuracy of Tree 43 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 44 is rejected.
# The accuracy of Tree 44 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 45 is rejected.
# The accuracy of Tree 45 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 46 is rejected.
# The accuracy of Tree 46 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 47 is rejected.
# The accuracy of Tree 47 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 48 is rejected.
# The accuracy of Tree 48 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 49 is rejected.
# The accuracy of Tree 49 is 0.88418
# sum(np.array(W)): [nan]
# eps: [nan]
# Tree 50 is rejected.
# The accuracy of Tree 50 is 0.88418

# %%
print(alphas)
if np.nan > 0 :
    print("np.nan > 0")
    
if np.array([np.inf]) > 0 :
    print("np.inf > 0")

print(np.array([np.nan, np.nan])/np.nan)

print(np.array([np.inf, np.inf])/sum(np.array([np.inf, np.inf])))
#clf2[0] = tree.DecisionTreeClassifier(criterion='entropy',max_depth=None)
# Out:
# [array([6.81218539]), array([4.5253648]), array([5.75293197]), array([5.4907297]), array([5.72790141]), array([5.57674117]), array([5.8238767]), array([5.61183225]), array([5.83003733]), array([5.92426125]), array([5.96773276]), array([5.84208165]), array([5.56233667]), array([6.49783805]), array([5.81777882]), array([5.4186236]), array([9.91351176]), array([6.02057311]), array([5.90846292]), array([5.21561591]), array([11.4866538]), array([5.21584211]), array([9.68200243]), array([10.4312928]), array([10.33124273]), array([15.61317416]), array([14.81385288]), array([14.74201812]), array([9.74110064]), array([10.43135443]), array([9.74104743]), array([20.86287981]), array([19.48216298]), array([inf]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan])]
# np.inf > 0
# [nan nan]
# [nan nan]
# /anaconda3/envs/face/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.

# %%
feature_record
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f9a7c0a9d72e> in <module>
# ----> 1 feature_record
#
# NameError: name 'feature_record' is not defined

# %%
importances = clf.feature_importances_ 
importance_frame = pd.DataFrame({'Importance': list(importances), 'Feature': list(X_train_onehot.columns)})
importance_frame.sort_values(by = 'Importance', inplace = True)
importance_frame.plot(kind = 'barh', x = 'Feature', figsize = (16,100), color = 'orange')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train_onehot, y_train)
print('The accuracy of Random Forest Classifier on testing set:', rfc.score(X_test_onehot, y_test))

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from xgboost import DMatrix
xgbc = XGBClassifier()
xgbc.fit(X_train_onehot, y_train)
print('The accuracy of eXtreme Gradient Boosting Classifier on testing set:', xgbc.score(X_test_onehot, y_test))

xgdmat = DMatrix(X_train_onehot, y_train)

# %%
from sklearn.model_selection import GridSearchCV
cv_params = {'max_depth': [3,5,7], 'min_child_weight': [1,3,5]}
ind_params = {'learning_rate': 0.1, 'n_estimators': 1000, 'seed':0, 'subsample': 0.8, 'colsample_bytree': 0.8, 
             'objective': 'binary:logistic'}
optimized_GBM = GridSearchCV(xgb.XGBClassifier(**ind_params), 
                            cv_params, 
                             scoring = 'accuracy', cv = 5, n_jobs = -1) 
# Optimize for accuracy since that is the metric used in the Adult Data Set notation

optimized_GBM.fit(X_train_onehot, y_train)

# %%
optimized_GBM.best_estimator_

# %%
optimized_GBM2 = GridSearchCV(cv=5, error_score='raise',
       estimator=XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
       gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
       min_child_weight=3, missing=None, n_estimators=1000, nthread=-1,
       objective='binary:logistic', reg_alpha=0, reg_lambda=1,
       scale_pos_weight=1, seed=0, silent=True, subsample=1),
       fit_params={}, iid=True, n_jobs=-1,
       param_grid={'subsample': [0.7, 0.8, 0.9], 'learning_rate': [0.1, 0.01]},
       pre_dispatch='2*n_jobs', refit=True, scoring='accuracy', verbose=0)

optimized_GBM2.fit(X_train_onehot, y_train)

# %%
optimized_GBM2.best_estimator_

# %%
our_params = {'eta': 0.1, 'seed':0, 'subsample': 0.8, 'colsample_bytree': 0.8, 
             'objective': 'binary:logistic', 'max_depth':3, 'min_child_weight':3} 
# Grid Search CV optimized settings

cv_xgb = xgb.cv(params = our_params, dtrain = xgdmat, num_boost_round = 3000, nfold = 5,
                metrics = ['error'], # Make sure you enter metrics inside a list or you may encounter issues!
                early_stopping_rounds = 100) # Look for early stopping that minimizes error

cv_xgb.tail(5)

# %%
from xgboost import plot_tree
from matplotlib import pyplot
# %matplotlib inline
import seaborn as sns
sns.set(font_scale = 1.5)

plot_tree(xgbc,rankdir='LR')
fig = pyplot.gcf()
fig.set_size_inches(150, 100)
#fig.savefig('tree.png')

# %%
from xgboost import plot_importance
plot_importance(xgbc)
fig = pyplot.gcf()
fig.set_size_inches(150, 100)

# %%
importances = xgbc.feature_importances_
importance_frame = pd.DataFrame({'Importance': list(importances), 'Feature': list(X_train_onehot.columns)})
importance_frame.sort_values(by = 'Importance', inplace = True)

# %%
importance_frame.plot(kind = 'barh', x = 'Feature', figsize = (16,100), color = 'orange')

# %%
fig.savefig("importance.png", format="PNG")
